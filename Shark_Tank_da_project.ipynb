# %%
#no. of successful deals and non deals
#most dealing episodes
#most expensve dealing episodes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Shark Tank.csv")

# %%
df.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
df["deal"].value_counts()
# Out:
# deal
# 1    65
# 0    52
# Name: count, dtype: int64

# %%
df.groupby(["episode_number"])["deal"].sum().reset_index().sort_values(by="deal", ascending=False)
# Out:
#     episode_number  deal
# 0                1     3
# 14              15     3
# 20              21     3
# 32              33     3
# 7                8     3
# 9               10     3
# 16              17     3
# 15              16     3
# 12              13     3
# 24              25     2
# 23              24     2
# 27              28     2
# 19              20     2
# 25              26     2
# 26              27     2
# 11              12     2
# 10              11     2
# 8                9     2
# 5                6     2
# 3                4     2
# 2                3     2
# 30              31     1
# 29              30     1
# 28              29     1
# 33              34     1
# 31              32     1
# 17              18     1
# 22              23     1
# 21              22     1
# 18              19     1
# 1                2     1
# 13              14     1
# 6                7     1
# 4                5     1
# 34              35     1

# %%
sns.catplot(x="deal",y="episode_number",data=df,hue="deal",kind="swarm");

# %%
A=df.groupby("episode_number")["deal_amount"].agg(["sum"]).sort_values(by="sum", ascending=False).reset_index()
A
# Out:
#     episode_number        sum
# 0               17  280.00000
# 1               13  255.00000
# 2               16  170.00000
# 3               21  160.00000
# 4               28  150.00000
# 5               25  150.00000
# 6                6  150.00000
# 7               20  140.00000
# 8                1  140.00000
# 9                8  136.00000
# 10              15  125.00005
# 11               4  125.00000
# 12              12  115.00000
# 13              26  115.00000
# 14              33  110.00000
# 15              27  100.00101
# 16               9  100.00000
# 17              14  100.00000
# 18               7  100.00000
# 19               5  100.00000
# 20               3   95.00000
# 21              10   85.00000
# 22              11   80.00000
# 23              30   80.00000
# 24              29   75.00000
# 25              31   75.00000
# 26               2   70.00000
# 27              24   60.00000
# 28              19   60.00000
# 29              22   60.00000
# ...

# %%
df.groupby("episode_number")["deal_amount"].sum().reset_index().max().reset_index()#.sort_values(by="max", ascending=False)(
# Out:
#             index      0
# 0  episode_number   35.0
# 1     deal_amount  280.0

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(A["episode_number"],A["sum"])
plt.xticks(A["episode_number"],rotation=90,fontsize=8);

# %%
df.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
all_sharks=df[df["total_sharks_invested"]==5].shape[0]
print(all_sharks)
df[df["total_sharks_invested"]==5]
# Out:
# 4
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 15         15.0  ...             1            1          1            1
# 49         25.0  ...             1            1          1            1
# ...

# %%
df["total_sharks_invested"].value_counts()
# Out:
# total_sharks_invested
# 0    52
# 1    22
# 2    20
# 3    14
# 4     5
# 5     4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(df["episode_number"],df["total_sharks_invested"])
plt.xticks(df["episode_number"],rotation=90,fontsize=8);

# %%
df.head(40)
# Out:
#     episode_number  pitch_number                      brand_name  \
# 0                1             1             BluePine Industries
# 1                1             2                   Booz scooters
# 2                1             3             Heart up my Sleeves
# 3                2             4                      Tagz Foods
# 4                2             5                  Head and Heart
# 5                2             6                    Agro tourism
# 6                3             7                     Qzense Labs
# 7                3             8                       Peeschute
# 8                3             9                            NOCD
# 9                4            10                           Cosiq
# 10               4            11                    JhaJi Achaar
# 11               4            12                          Bummer
# 12               5            13                     Revamp Moto
# ...

# %%
df[(df["pitcher_ask_amount"]==df["deal_amount"]) & (df["ask_equity"]==df["deal_equity"])]
# Out:
#     episode_number  pitch_number    brand_name                 idea  deal  \
# 21               8            22  Beyond Snack  Kerala Banana Chips     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 21                50.0         2.5         2000.0         50.0          2.5
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 21  ...             1            0          1            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 21            0            0                      2              25.0
#
#     equity_per_shark
# 21              1.25
#
# [1 rows x 28 columns]

# %%
df.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
li=list(df.columns[-4:-11:-1])
print(li)
def sharks(name):
  for i in li:
    #if name==i[:-5]:
     #   continue
    shark=name+"_deal"
    deal=df[(df[i]==1) & (df[shark]==1)]
    print(name,len(deal)," deal with",i[:-5])
    print(f"amount per shark {name}",deal["amount_per_shark"])
    print(f"equity per shark {name}",deal["equity_per_shark"])
# Out:
# ['ghazal_deal', 'peyush_deal', 'vineeta_deal', 'namita_deal', 'aman_deal', 'anupam_deal', 'ashneer_deal']

# %%
sharks("ashneer")
# Out:
# ashneer 1  deal with ghazal
# amount per shark ashneer 110    10.0
# Name: amount_per_shark, dtype: float64
# equity per shark ashneer 110    5.0
# Name: equity_per_shark, dtype: float64
# ashneer 9  deal with peyush
# amount per shark ashneer 29     10.0
# 38     25.0
# 49     10.0
# 50     50.0
# 58     15.0
# 63     20.0
# 67     20.0
# 108    20.0
# 109     5.0
# Name: amount_per_shark, dtype: float64
# equity per shark ashneer 29     1.000000
# 38     2.500000
# 49     5.000000
# 50     5.000000
# 58     2.500000
# 63     2.000000
# 67     1.333333
# 108    3.333333
# 109    5.000000
# Name: equity_per_shark, dtype: float64
# ashneer 6  deal with vineeta
# amount per shark ashneer 0      25.000000
# 1      20.000000
# 15     20.000000
# 64     33.333333
# 110    10.000000
# 114    10.000000
# Name: amount_per_shark, dtype: float64
# equity per shark ashneer 0       5.333333
# 1      25.000000
# 15      3.000000
# 64      5.000000
# 110     5.000000
# 114     7.500000
# ...

# %%
sharks("namita")
# Out:
# namita 4  deal with ghazal
# amount per shark namita 79     20.000000
# 85      0.000253
# 91     25.000000
# 110    10.000000
# Name: amount_per_shark, dtype: float64
# equity per shark namita 79     1.2
# 85     1.0
# 91     7.0
# 110    5.0
# Name: equity_per_shark, dtype: float64
# namita 8  deal with peyush
# amount per shark namita 27     8.333333
# 36    35.000000
# 49    10.000000
# 50    50.000000
# 58    15.000000
# 63    20.000000
# 79    20.000000
# 85     0.000253
# Name: amount_per_shark, dtype: float64
# equity per shark namita 27    6.666667
# 36    1.000000
# 49    5.000000
# 50    5.000000
# 58    2.500000
# 63    2.000000
# 79    1.200000
# 85    1.000000
# Name: equity_per_shark, dtype: float64
# namita 5  deal with vineeta
# amount per shark namita 15     20.0
# 79     20.0
# 91     25.0
# 95     40.0
# 110    10.0
# Name: amount_per_shark, dtype: float64
# equity per shark namita 15     3.0
# 79     1.2
# 91     7.0
# 95     3.0
# 110    5.0
# ...

# %%
df.groupby("ashneer_deal")["amount_per_shark"].sum()
# Out:
# ashneer_deal
# 0    1627.166936
# 1     494.333333
# Name: amount_per_shark, dtype: float64

# %%
df.groupby("ashneer_deal")["equity_per_shark"].sum()
# Out:
# ashneer_deal
# 0    560.03
# 1     93.25
# Name: equity_per_shark, dtype: float64

# %%
df.groupby("ashneer_deal")["amount_per_shark"].max()
# Out:
# ashneer_deal
# 0    100.0
# 1     70.0
# Name: amount_per_shark, dtype: float64

# %%
sharks("anupam")
# Out:
# anupam 3  deal with ghazal
# amount per shark anupam 75    25.000000
# 79    20.000000
# 85     0.000253
# Name: amount_per_shark, dtype: float64
# equity per shark anupam 75    17.5
# 79     1.2
# 85     1.0
# Name: equity_per_shark, dtype: float64
# anupam 12  deal with peyush
# amount per shark anupam 22     28.000000
# 28     10.000000
# 35     13.333333
# 36     35.000000
# 37     25.000000
# 38     25.000000
# 49     10.000000
# 63     20.000000
# 67     20.000000
# 79     20.000000
# 85      0.000253
# 108    20.000000
# Name: amount_per_shark, dtype: float64
# equity per shark anupam 22     16.650000
# 28      6.666667
# 35      8.000000
# 36      1.000000
# 37     10.000000
# 38      2.500000
# 49      5.000000
# 63      2.000000
# 67      1.333333
# 79      1.200000
# 85      1.000000
# 108     3.333333
# Name: equity_per_shark, dtype: float64
# anupam 6  deal with vineeta
# amount per shark anupam 2      12.5
# 9      25.0
# 15     20.0
# 66     17.5
# 79     20.0
# ...
